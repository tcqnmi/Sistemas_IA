# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

datos = {
    "alfa": [1, 2, 4, 8, np.nan, 9, 45],
    "beta": [8, 14, np.nan, 6, 1, 6, 46],
    "gamma": [5, 4, 4, 4, 4, 4, np.nan],
    "salida": [np.nan, 1, 18, 14, 10, 1, 19]
}

df = pd.DataFrame(data=datos)
copia = df.copy()
df
# Out:
#    alfa  beta  gamma  salida
# 0   1.0   8.0    5.0     NaN
# 1   2.0  14.0    4.0     1.0
# 2   4.0   NaN    4.0    18.0
# 3   8.0   6.0    4.0    14.0
# 4   NaN   1.0    4.0    10.0
# 5   9.0   6.0    4.0     1.0
# 6  45.0  46.0    NaN    19.0

# %%
# ¿Cuantos valores desconocidos tenemos por variable?
df.isna().sum()
# Out:
# alfa      1
# beta      1
# gamma     1
# salida    1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# alfa      1
# beta      1
# gamma     1
# salida    1
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#    alfa  beta  gamma  salida
# 1   2.0  14.0    4.0     1.0
# 3   8.0   6.0    4.0    14.0
# 5   9.0   6.0    4.0     1.0

# %%
df = copia.copy()
df.fillna(value=0, inplace=True)
df
# Out:
#    alfa  beta  gamma  salida
# 0   1.0   8.0    5.0     0.0
# 1   2.0  14.0    4.0     1.0
# 2   4.0   0.0    4.0    18.0
# 3   8.0   6.0    4.0    14.0
# 4   0.0   1.0    4.0    10.0
# 5   9.0   6.0    4.0     1.0
# 6  45.0  46.0    0.0    19.0

# %%
df = copia.copy()
df["alfa"].fillna(value=df["alfa"].mean(), inplace=True)
df["beta"].fillna(value=df["beta"].median(), inplace=True)
df["gamma"].fillna(value=df["gamma"].mode()[0], inplace=True)
df
# Out:
#    alfa  beta  gamma  salida
# 0   1.0   8.0    5.0     NaN
# 1   2.0  14.0    4.0     1.0
# 2   4.0   7.0    4.0    18.0
# 3   8.0   6.0    4.0    14.0
# 4  11.5   1.0    4.0    10.0
# 5   9.0   6.0    4.0     1.0
# 6  45.0  46.0    4.0    19.0

# %%
df = copia.copy()

from sklearn.impute import SimpleImputer

si = SimpleImputer(missing_values=np.nan, strategy="mean")
df = pd.DataFrame(data= si.fit_transform(df), columns=df.columns)
df
# Out:
#    alfa  beta     gamma  salida
# 0   1.0   8.0  5.000000    10.5
# 1   2.0  14.0  4.000000     1.0
# 2   4.0  13.5  4.000000    18.0
# 3   8.0   6.0  4.000000    14.0
# 4  11.5   1.0  4.000000    10.0
# 5   9.0   6.0  4.000000     1.0
# 6  45.0  46.0  4.166667    19.0

# %%
df = copia.copy()

si = SimpleImputer(missing_values=np.nan, strategy="median").set_output(transform="pandas")
df = si.fit_transform(df)
df
# Out:
#    alfa  beta  gamma  salida
# 0   1.0   8.0    5.0    12.0
# 1   2.0  14.0    4.0     1.0
# 2   4.0   7.0    4.0    18.0
# 3   8.0   6.0    4.0    14.0
# 4   6.0   1.0    4.0    10.0
# 5   9.0   6.0    4.0     1.0
# 6  45.0  46.0    4.0    19.0

# %%
from sklearn.impute import KNNImputer
df = copia.copy()

knn = KNNImputer(missing_values=np.nan).set_output(transform="pandas")
df = knn.fit_transform(df)
df
# Out:
#    alfa  beta  gamma  salida
# 0   1.0   8.0    5.0     8.8
# 1   2.0  14.0    4.0     1.0
# 2   4.0   7.0    4.0    18.0
# 3   8.0   6.0    4.0    14.0
# 4   4.8   1.0    4.0    10.0
# 5   9.0   6.0    4.0     1.0
# 6  45.0  46.0    4.0    19.0
