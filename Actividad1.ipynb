# %% [markdown]
# Importa las librerías necesarias

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %% [markdown]
# Crea un data frame para cargar los datos del fichero autos-85.csv

# %%
df = pd.read_csv("datasets/autos-85/autos-85.csv")

# %% [markdown]
# Crea una copia del data frame para poderla recuperar más adelante si es necesario

# %%
df_copia = df.copy()

# %% [markdown]
# Explora los datos qué incluye el dataset

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %% [markdown]
# Identifica las variables qué tienen valores desconocidos (NaN) calculando el total de valores de este tipo qué hay en cada columna

# %%
variables_con_nan = df.isnull().sum()
variables_con_nan
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# Muestra en consola las filas (filas del data frame) qué tienen valores desconocidos.

# %%
filas_con_nan = df[df.isnull().any(axis=1)]

# %% [markdown]
# Elimina del dataset las muestras qué tengan valores perdidos en las variables horsepower y peak-rpm

# %%
df = df.dropna(subset=['horsepower', 'peak-rpm'])

# %% [markdown]
#  Muestra en consola las filas qué tienen valores desconocidos para la variable bore

# %%
filas_bore_nan = df[df['bore'].isnull()]

# %% [markdown]
# Sustituye los valores desconocidos de la variable bore por la media

# %%
media_bore = df['bore'].mean()
df['bore'].fillna(media_bore, inplace=True)
# Out:
# C:\Users\tamar\AppData\Local\Temp\ipykernel_21956\3642640017.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bore'].fillna(media_bore, inplace=True)

# %% [markdown]
# Calcula el número de valores desconocidos en la variable bore

# %%
num_nan_bore = df['bore'].isnull().sum()
num_nan_bore
# Out:
# 0

# %% [markdown]
# Muestra en consola las filas en las qué se ha realizado la sustitución

# %%
filas_sustituidas_bore = df[df['bore'].isnull()]
filas_sustituidas_bore
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# Muestra en consola las filas qué tienen valores desconocidos para la variable num-of-doors

# %%
filas_num_of_doors_nan = df[df['num-of-doors'].isnull()]
print("Filas con valores desconocidos en 'num-of-doors':")
print(filas_num_of_doors_nan)
# Out:
# Filas con valores desconocidos en 'num-of-doors':
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 27          1              148.0  dodge       gas      turbo          NaN
# 63          0                NaN  mazda    diesel        std          NaN
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 27      sedan          fwd           front        93.7  ...           98
# 63      sedan          fwd           front        98.8  ...          122
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 27         mpfi  3.03    3.39               7.6      102.0    5500.0       24
# 63          idi  3.39    3.39              22.7       64.0    4650.0       36
#
#     highway-mpg    price
# 27           30   8558.0
# 63           42  10795.0
#
# [2 rows x 26 columns]

# %% [markdown]
# Sustituye los valores desconocidos de la variable num-of-doors por la moda

# %%
moda_num_of_doors = df['num-of-doors'].mode()[0]
df['num-of-doors'].fillna(moda_num_of_doors, inplace=True)
# Out:
# C:\Users\tamar\AppData\Local\Temp\ipykernel_21956\4249056992.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num-of-doors'].fillna(moda_num_of_doors, inplace=True)

# %% [markdown]
# Calcula el número de valores desconocidos en la variable num-of-doors

# %%
num_nan_num_of_doors = df['num-of-doors'].isnull().sum()
print("\nNúmero de valores desconocidos en 'num-of-doors' después de la sustitución:", num_nan_num_of_doors)
# Out:
# Número de valores desconocidos en 'num-of-doors' después de la sustitución: 0

# %% [markdown]
# Muestra en consola las filas en las qué se ha realizado la sustitución

# %%
filas_sustituidas_num_of_doors = df[df['num-of-doors'].isnull()]
print("\nFilas con valores desconocidos en 'num-of-doors' después de la sustitución:")
print(filas_sustituidas_num_of_doors)
# Out:
# Filas con valores desconocidos en 'num-of-doors' después de la sustitución:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# Repite los pasos anteriores para las variables bore y num-of-doors sobre una copia del data frame utilizando la clase SimpleImputer de la librería sklearn

# %%
df_copia = df.copy()

# Utilizar SimpleImputer para reemplazar valores desconocidos con la media para bore
si_bore = SimpleImputer(missing_values=np.nan, strategy="mean")
df_copia['bore'] = si_bore.fit_transform(df_copia[['bore']])


# Utilizar SimpleImputer para reemplazar valores desconocidos con la moda para num-of-doors
si_num_of_doors = SimpleImputer(missing_values=np.nan, strategy="most_frequent")
df_copia['num-of-doors'] = si_num_of_doors.fit_transform(df_copia[['num-of-doors']])

df_copia
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %% [markdown]
# Muestra en consola las filas qué tienen valores desconocidos para la variable normalized-losses

# %%
filas_normalized_losses_nan = df_copia[df_copia['normalized-losses'].isnull()]
print("Filas con valores desconocidos en 'normalized-losses':")
print(filas_normalized_losses_nan)
# Out:
# Filas con valores desconocidos en 'normalized-losses':
#      symboling  normalized-losses           make fuel-type aspiration  \
# 0            3                NaN    alfa-romero       gas        std
# 1            3                NaN    alfa-romero       gas        std
# 2            1                NaN    alfa-romero       gas        std
# 5            2                NaN           audi       gas        std
# 7            1                NaN           audi       gas        std
# 9            0                NaN           audi       gas      turbo
# 14           1                NaN            bmw       gas        std
# 15           0                NaN            bmw       gas        std
# 16           0                NaN            bmw       gas        std
# 17           0                NaN            bmw       gas        std
# 43           0                NaN          isuzu       gas        std
# 44           1                NaN          isuzu       gas        std
# ...

# %% [markdown]
# Estima el valor desconocido para las muestras de la variable normalized-losses utilizando el algoritmo KNN

# %%
knn_imputer = KNNImputer(missing_values=np.nan)
df_copia['normalized-losses'] = knn_imputer.fit_transform(df_copia[['normalized-losses']])
df_copia
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %% [markdown]
# Muestra en consola las filas en las qué se ha realizado la sustitución

# %%
filas_sustituidas_normalized_losses = df_copia[df_copia['normalized-losses'].isnull()]
print("\nFilas con valores desconocidos en 'normalized-losses' después de la sustitución:")
print(filas_sustituidas_normalized_losses)
# Out:
# Filas con valores desconocidos en 'normalized-losses' después de la sustitución:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]
