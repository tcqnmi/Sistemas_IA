# %%
import numpy as np
import pandas as pd

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

datos=load_digits()
x = datos.data
y = datos.target

# Exploración de los datos
datos.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %%
print(datos['target'])

#Tenemos 10 digitos, osea que 10 etiquetas ( es el dataset de los pixeles que se "manchan" al escribir un numero para distinguir escritura manual)
# Out:
# [0 1 2 ... 8 9 8]

# %%
df = pd.DataFrame(data = datos.data)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1797 entries, 0 to 1796
# Data columns (total 64 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1797 non-null   float64
#  1   1       1797 non-null   float64
#  2   2       1797 non-null   float64
#  3   3       1797 non-null   float64
#  4   4       1797 non-null   float64
#  5   5       1797 non-null   float64
#  6   6       1797 non-null   float64
#  7   7       1797 non-null   float64
#  8   8       1797 non-null   float64
#  9   9       1797 non-null   float64
#  10  10      1797 non-null   float64
#  11  11      1797 non-null   float64
#  12  12      1797 non-null   float64
#  13  13      1797 non-null   float64
#  14  14      1797 non-null   float64
#  15  15      1797 non-null   float64
#  16  16      1797 non-null   float64
#  17  17      1797 non-null   float64
#  18  18      1797 non-null   float64
#  19  19      1797 non-null   float64
# ...

# %%
import matplotlib.pyplot as plt
from sklearn import metrics, svm
from sklearn.model_selection import train_test_split

# Mostramos el primer dígito en pantalla

plt.gray()
plt.imshow(datos.images[0])

# %%
# Mostramos el resto
# Configuramos la distribución de la tabla de gráficas que vamos a generar
# 10 filas y 10 columnas

fig, ax = plt.subplots(nrows=10, ncols=10, figsize=(10,10))

# Aplana ax en una dimensión
ax = ax.flatten()

for i in range(100):
    # Muestra los datos como una imagen
    ax[i].imshow(datos.images[i],cmap=plt.cm.gray_r)
    # Título
    ax[i].set_title(f"Cifra: {datos.target[i]}")
    # Quitamos la decoración a la representación gráfica
    ax[i].axis('off')
plt.tight_layout()
plt.show()
