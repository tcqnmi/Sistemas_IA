# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

datos=pd.read_csv("datasets/dataset.csv")
x = datos.values

# %%
#Representación gráfica
plt.figure(figsize=(8,6))
plt.scatter(x[:,0],x[:,1], c="red", s=50)
plt.title('DBSCAN Clustering (make circles)')
plt.xlabel('x1')
plt.xlabel('x2')
# Out:
# Text(0.5, 0, 'x2')
